# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
GROQ_API_KEY=os.getenv('GROQ_API_KEY')

# %%
from groq import Groq

client = Groq()
completion = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
      {
        "role": "system",
        "content": "You are a helpful travel assistant. Be brief, factual, and use bullet points when helpful.\n"
      },
      {
        "role": "user",
        "content": "I want to visit India"
      }
    ],
    temperature=1,
    max_completion_tokens=8192,
    top_p=1,
    reasoning_effort="medium",
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# **Quick Guide to Visiting India**
#
# - **Visa**
#   - Most travelers need an e‑visa (tourist) or regular visa. Apply online via the official Indian visa portal.
#   - Processing time: 2–4 business days; keep a printed copy.
#
# - **Best Time to Visit**
#   - **October–March**: Cooler in north, mild in south. Ideal for most destinations.
#   - **June–September**: Monsoon season; good for lush landscapes but check rainfall in specific areas.
#
# - **Must‑See Highlights**
#   - **North**: Taj Mahal (Agra), Jaipur, Varanasi, Shimla.
#   - **South**: Kerala backwaters, Hampi, Mysore.
#   - **East**: Darjeeling, Puri, Bhubaneswar.
#   - **West**: Goa beaches, Udaipur, Pune.
#
# - **Getting Around**
#   - *Domestic flights* for long distances (Air India, IndiGo, SpiceJet).
#   - *Trains* (Indian Railways) for scenic routes; book early for premium coaches.
#   - *Local transport*: auto‑rickshaws, metro (Delhi, Mumbai), buses (state services).
#
# - **Safety & Health**
# ...

# %%
from groq import Groq
import os
from dotenv import load_dotenv
load_dotenv()
GROQ_API_KEY=os.getenv('GROQ_API_KEY')
client = Groq(api_key=os.getenv("GROQ_API_KEY"))

def agent(user_input):
    completion = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
      {
        "role": "system",
        "content": """You are a concise, helpful travel assistant. Answer only travel-related queries with practical routes, short itineraries, neighborhood/lodging tips, typical cost ranges (not live prices), and visa/safety reminders.

                    1.Stay in scope: If a request isn’t about travel, politely decline and redirect to travel topics.

                    2.Style: Be brief, factual, and use clear bullets or a tiny table; ask only minimal follow-ups when essential.

                    3.When useful, add a “Quick Guide” with: Visa, Best Time, Must-See Highlights (by region), Getting Around, Safety & Health, and Emergency Numbers"""
      },
      {
        "role": "user",
        "content": user_input
      }
    ],
    temperature=1,
    max_completion_tokens=8192,
    top_p=1,
    reasoning_effort="medium",
    stream=True,
    stop=None
    )
    response=""
    for chunk in completion:
        response+=chunk.choices[0].delta.content

    return response

# %%
from agent import get_response

# %%
from IPython.display import display_markdown

# %%
res=get_response("Give me the best places to visit for fall in us?")
display_markdown(res, raw=True)
# Out:
# **Best fall destinations in the U.S.**
#
# - **New England (Massachusetts, Vermont, New Hampshire)**
#   - Iconic foliage, classic New England towns, harvest festivals.
#
# - **Finger Lakes, New York**
#   - Vibrant colors around wine country, scenic drives, fall festivals.
#
# - **Shenandoah National Park, Virginia**
#   - Blue Ridge Parkway views, hiking with crisp air.
#
# - **Great Smoky Mountains, Tennessee/North Carolina**
#   - Deep red & gold, family‑friendly hikes, historic towns.
#
# - **Colorado Rockies (Rocky Mountain National Park)**
#   - High‑altitude colors, mountain vistas, cooler temperatures.
#
# - **Oregon Coast & Columbia River Gorge**
#   - Dramatic coastal weather, autumnal light, coastal walks.
#
# - **Napa Valley, California**
#   - Harvest season, wine tastings, fall foliage.
#
# - **Mackinac Island, Michigan**
#   - Historic charm, maple‑syrup season, autumn lights.
#
# - **South Dakota Badlands & Black Hills**
# ...
